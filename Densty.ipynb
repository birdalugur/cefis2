# %%
from importlib import reload

# %%
reload(den)
# Out:
# <module 'src.density' from 'C:\\Users\\ugur.eren\\Python Codes\\cefis2\\src\\density.py'>

# %%
import pandas as pd
import numpy as np
import src.density as den

# %%
cols = ['time period','duration','amplitude']

# %%
data = pd.read_csv('6AU8_6BU8.csv',usecols=cols)

# %%
veri = data.loc['18:00:00']

# %%
density= den.Density(veri)

# %%
density.get_distribution('amplitude').normal.swaplevel(0,1,axis=1).sort_index()
# Out:
#                     conditional_distribution
# amplitude duration
# -13.125   48.0                      1.000000
# -11.875   14.0                      1.000000
# -11.250   3.0                       0.500000
#           23.0                      0.500000
# -10.000   1.0                       0.200000
#           14.0                      0.200000
#           35.0                      0.200000
#           50.0                      0.200000
#           138.0                     0.200000
# -9.375    211.0                     1.000000
# -8.125    2.0                       1.000000
#           18.0                      1.000000
#           2.0                       0.333333
#           18.0                      0.333333
#           120.0                     0.333333
# -6.250    155.0                     1.000000
#           9.0                       0.500000
#           21.0                      0.500000
#           2.0                       0.166667
# ...

# %%
density.get_distribution('amplitude').normal.swaplevel(0,1,axis=0).sort_index()
# Out:
#                     conditional_distribution
# amplitude duration
# -13.125   48.0                      1.000000
# -11.875   14.0                      1.000000
# -11.250   3.0                       0.500000
#           23.0                      0.500000
# -10.000   1.0                       0.200000
#           14.0                      0.200000
#           35.0                      0.200000
#           50.0                      0.200000
#           138.0                     0.200000
# -9.375    211.0                     1.000000
# -8.125    2.0                       1.000000
#           18.0                      1.000000
#           2.0                       0.333333
#           18.0                      0.333333
#           120.0                     0.333333
# -6.250    155.0                     1.000000
#           9.0                       0.500000
#           21.0                      0.500000
#           2.0                       0.166667
# ...
